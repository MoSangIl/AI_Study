# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation

import datetime

# %%
data = pd.read_csv('dataset/etherium_TSdata.csv')
data.head()
# Out:
#            Date     Open*    High     Low   Close**          Volume  \
# 0     14.Sep.15  0.940566    0.95    0.87  0.875622         741,085
# 1     15.Sep.15  0.875189    1.05    0.88   0.94441         703,390
# 2     16.Sep.15  0.941977    0.95    0.90  0.907175         615,593
# 3     17.Sep.15  0.906865    0.91    0.83  0.874231         897,940
# 4     18.Sep.15  0.874574    0.89    0.83  0.853685         484,622
# ...         ...       ...     ...     ...       ...             ...
# 1822   9.Sep.20    337.82  359.16  332.16    351.11  14,547,933,520
# 1823  10.Sep.20    351.43  377.39  351.11     368.1  31,421,134,556
# 1824  11.Sep.20    368.12  376.63  355.58     374.7  27,296,269,329
# 1825  12.Sep.20     374.6  387.54  367.84    387.18  13,295,405,814
# 1826  13.Sep.20    387.52  388.96  354.34    365.57  15,005,899,191
#
#           Market Cap
# 0         64,084,135
# 1         69,141,409
# 2         66,437,873
# 3         64,046,216
# 4         62,561,883
# ...              ...
# 1822  39,512,826,170
# 1823  41,430,053,162
# 1824  42,177,302,259
# 1825  43,588,199,422
# 1826  41,160,025,962
#
# [1827 rows x 7 columns]

# %% [markdown]
# ## Compute Mid Price

# %%
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2

# %% [markdown]
# ## Create Windows
#
# Window: 50
# 최근 50일 데이터를 보고 다음을 예측한다.

# %%
seq_len = 50
sequence_length = seq_len + 10

result = []

for index in range((len(mid_prices) - sequence_length) // 10 + 1):
    #print(index)
    result.append(mid_prices[index*10: index*10 + sequence_length]) # slicing

# %% [markdown]
# ## Normalize Data
#
# 모델이 잘 예측하게 함.
#
# ### How?
#
# (맨 처음 값 - 해당 값) - 1 -> -1 해주는 이유는 처음 값을 0 으로 만들기 위함

# %%
normalized_data = []

for window in result:
    normalized_window = [((float(p) / float(window[0])) - 1) for p in window]
    normalized_data.append(normalized_window)

result = np.array(normalized_data)

# split train and test data
row = int(round(result.shape[0] * 0.9))
train = result[:row, :]
np.random.shuffle(train)

x_train = train[:, :50]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, 50:]

x_test = result[row:, :50]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, 50:]

print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (159, 50, 1) (18, 50, 1)
# (159, 10) (18, 10)

# %% [markdown]
#  ## Build a Model

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1)))

model.add(LSTM(64, return_sequences=False))

model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='rmsprop')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense (Dense)                (None, 10)                650
# =================================================================
# Total params: 40,490
# Trainable params: 40,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##
# 16/16 [==============================] - 0s 30ms/step - loss: 13.4461 - val_loss: 5.4042
# Epoch 79/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.4168 - val_loss: 5.4078
# Epoch 80/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.4267 - val_loss: 5.5308
# Epoch 81/100
# 16/16 [==============================] - 0s 28ms/step - loss: 13.4289 - val_loss: 5.4803
# Epoch 82/100
# 16/16 [==============================] - 0s 28ms/step - loss: 13.3940 - val_loss: 5.4768
# Epoch 83/100
# 16/16 [==============================] - 0s 29ms/step - loss: 13.3929 - val_loss: 5.4484
# Epoch 84/100
# 16/16 [==============================] - 1s 32ms/step - loss: 13.3593 - val_loss: 5.3767
# Epoch 85/100
# 16/16 [==============================] - 0s 28ms/step - loss: 13.3371 - val_loss: 5.4344
# Epoch 86/100
# 16/16 [==============================] - 0s 29ms/step - loss: 13.3118 - val_loss: 5.3709
# Epoch 87/100
# 16/16 [==============================] - 1s 33ms/step - loss: 13.3014 - val_loss: 5.4761
# Epoch 88/100
# 16/16 [==============================] - 1s 32ms/step - loss: 13.3053 - val_loss: 5.4146
# Epoch 89/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.2970 - val_loss: 5.4421
# Epoch 90/100
# 16/16 [==============================] - 0s 31ms/step - loss: 13.2880 - val_loss: 5.3839
# Epoch 91/100
# 16/16 [==============================] - 1s 32ms/step - loss: 13.2800 - val_loss: 5.3754
# Epoch 92/100
# 16/16 [==============================] - 0s 31ms/step - loss: 13.2653 - val_loss: 5.3443
# Epoch 93/100
# 16/16 [==============================] - 0s 31ms/step - loss: 13.2660 - val_loss: 5.3673
# Epoch 94/100
# 16/16 [==============================] - 0s 31ms/step - loss: 13.2743 - val_loss: 5.3580
# Epoch 95/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.2731 - val_loss: 5.3393
# Epoch 96/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.2687 - val_loss: 5.3915
# Epoch 97/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.2659 - val_loss: 5.3984
# Epoch 98/100
# 16/16 [==============================] - 0s 29ms/step - loss: 13.2599 - val_loss: 5.4196
# Epoch 99/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.2698 - val_loss: 5.3407
# Epoch 100/100
# 16/16 [==============================] - 0s 30ms/step - loss: 13.2645 - val_loss: 5.3557

# %% [markdown]
# ## Prediction

# %%
pred = model.predict(x_test)

# pred / y_test -> 2차원 이되, 일렬 데이터로 변경..
pred = pred.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend()
plt.show()

# %%
ax.legend?
