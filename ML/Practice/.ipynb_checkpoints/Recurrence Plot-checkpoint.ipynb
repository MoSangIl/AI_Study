# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform

sns.set()

# %%
date_rng = pd.date_range(start='1/1/2018', end='1/08/2018', freq='H')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0, 100, size=(len(data_rng)))
df.head(10)
# Out:
#                  date  data
# 0 2018-01-01 00:00:00    66
# 1 2018-01-01 01:00:00    12
# 2 2018-01-01 02:00:00     5
# 3 2018-01-01 03:00:00    19
# 4 2018-01-01 04:00:00    72
# 5 2018-01-01 05:00:00     3
# 6 2018-01-01 06:00:00     8
# 7 2018-01-01 07:00:00    60
# 8 2018-01-01 08:00:00    92
# 9 2018-01-01 09:00:00    56

# %%
df['data'].plot(figsize=(16, 6))
# Out:
# <AxesSubplot:>

# %%
def rec_plot(s, eps=0.10, steps=10):
    d = pdist(s[:, None])
    d = np.floor(d/eps)
    d[d>steps] = steps
    Z = squareform(d)
    return Z

# %%
d = pdist((df['data'])[:, None])
d
print(df['data'][:, None])
print(pdist(df['data'][:, None]))
# Out:
# [[66]
#  [12]
#  [ 5]
#  [19]
#  [72]
#  [ 3]
#  [ 8]
#  [60]
#  [92]
#  [56]
#  [91]
#  [ 9]
#  [11]
#  [95]
#  [80]
#  [98]
#  [43]
#  [64]
#  [36]
#  [24]
#  [65]
#  [99]
#  [91]
#  [82]
#  [14]
#  [74]
#  [62]
#  [76]
#  [67]
#  [56]
#  [96]
#  [90]
#  [38]
#  [60]
#  [23]
#  [71]
#  [17]
#  [77]
#  [ 1]
#  [85]
#  [49]
#  [75]
#  [45]
#  [91]
#  [41]
#  [45]
#  [62]
#  [36]
#  [76]
#  [ 2]
#  [74]
#  [36]
#  [60]
#  [ 1]
#  [97]
#  [50]
#  [93]
#  [ 6]
#  [ 5]
#  [60]
#  [27]
#  [42]
#  [10]
#  [30]
#  [ 1]
#  [85]
#  [47]
#  [40]
#  [43]
#  [66]
#  [66]
#  [43]
#  [31]
#  [99]
#  [73]
#  [84]
#  [61]
#  [73]
#  [10]
#  [45]
#  [74]
#  [72]
#  [89]
#  [28]
#  [71]
#  [59]
#  [67]
#  [66]
#  [12]
#  [ 3]
#  [87]
#  [34]
#  [68]
#  [44]
#  [28]
#  [65]
#  [ 9]
#  [45]
#  [21]
#  [ 4]
#  [69]
#  [59]
#  [20]
#  [98]
#  [61]
#  [45]
#  [62]
#  [43]
#  [74]
#  [99]
#  [ 5]
#  [40]
#  [84]
#  [56]
#  [96]
#  [58]
#  [96]
#  [62]
#  [53]
#  [76]
#  [42]
#  [89]
#  [21]
#  [42]
#  [47]
#  [78]
#  [ 5]
#  [63]
#  [56]
#  [75]
#  [28]
#  [46]
#  [84]
#  [77]
#  [ 2]
#  [27]
#  [80]
#  [22]
#  [72]
#  [51]
#  [64]
#  [30]
#  [94]
#  [94]
#  [80]
#  [60]
#  [39]
#  [89]
#  [20]
#  [48]
#  [52]
#  [81]
#  [73]
#  [ 3]
#  [16]
#  [37]
#  [51]
#  [69]
#  [58]
#  [62]
#  [57]
#  [96]
#  [72]
#  [ 8]
#  [15]
#  [38]
#  [ 1]
#  [ 3]
#  [87]]
# [54. 61. 47. ...  2. 86. 84.]
# <ipython-input-21-c3ca6564fc48>:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   d = pdist((df['data'])[:, None])
# <ipython-input-21-c3ca6564fc48>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   print(df['data'][:, None])
# <ipython-input-21-c3ca6564fc48>:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   print(pdist(df['data'][:, None]))

# %%
s = df['data']
eps = 0.80
steps = 10

d = pdist(s[:, None])
d = np.floor(d/eps)
d[d>steps] = steps
Z = squareform(d)
print(Z)
# Out:
# [[ 0. 10. 10. ... 10. 10. 10.]
#  [10.  0.  8. ... 10. 10. 10.]
#  [10.  8.  0. ...  5.  2. 10.]
#  ...
#  [10. 10.  5. ...  0.  2. 10.]
#  [10. 10.  2. ...  2.  0. 10.]
#  [10. 10. 10. ... 10. 10.  0.]]
# <ipython-input-32-bd5923feaf87>:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   d = pdist(s[:, None])

# %%
a = []

a.append(rec_plot(df['data'], eps=0.10))
a.append(rec_plot(df['data'], eps=0.30))
a.append(rec_plot(df['data'], eps=0.60))
a.append(rec_plot(df['data'], eps=0.80))
a.append(rec_plot(df['data'], eps=5))
# Out:
# <ipython-input-10-7cf2f9a20bff>:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   d = pdist(s[:, None])

# %%
fig, axs = plt.subplots(1, len(a), figsize=(16, 4), sharey=True)

for i, obj in enumerate(a):
    axs[i].imshow(obj, cmap='gray')
